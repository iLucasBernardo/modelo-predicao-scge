# %% [markdown]
# Importações de Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error
import io

# %%
dados = pd.read_csv('../Prata.csv', sep=';', encoding='utf-8', decimal=',')
dados.tail(20)
# Out:
#     data_Lançamento  1. Pessoal Ativo  2. Pessoal Inativo e Pensionistas  \
# 127         08-2024      9.159031e+08                       6.669900e+08
# 128         09-2024      9.654408e+08                       6.675743e+08
# 129         10-2024      1.148392e+09                       6.815468e+08
# 130         11-2024      9.434185e+08                       5.868478e+08
# 131         12-2024      2.294684e+09                       1.315921e+09
# 132         01-2025      1.007702e+09                       6.708176e+08
# 133         02-2025      9.816163e+08                       6.751124e+08
# 134         03-2025      9.609695e+08                       6.769911e+08
# 135         04-2025      9.602988e+08                       6.766460e+08
# 136         05-2025      9.645936e+08                       6.758968e+08
# 137         06-2025      1.061595e+09                       7.172346e+08
# 138         07-2025      1.031537e+09                       7.134307e+08
# 139         08-2025      1.027499e+09                       7.165844e+08
# 140         09-2025      1.112812e+09                       7.220335e+08
# 141         10-2025      1.213996e+09                       7.256230e+08
# 142         11-2025      1.046065e+09                       7.260036e+08
# 143         12-2025      8.831733e+08                       7.255855e+08
# 144         01-2026      1.068828e+09                       7.304234e+08
# 145         02-2026      1.041557e+09                       7.302417e+08
# 146         03-2026               NaN                                NaN
#
#      4. Indenizações por Demissão e Incentivo à Demissão  \
# 127                                           997281.2
# 128                                          1184812.0
# 129                                          1746846.7
# 130                                           819858.6
# 131                                          1166479.6
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
#      5. Decorrentes de Decisão Judicial  6. Despesas de Exercicios Anteriores  \
# 127                                 0.0                              800581.2
# 128                                 0.0                             1038322.4
# 129                             63971.1                             2178769.0
# 130                                 0.0                             2992505.0
# 131                         407623572.8                             1215519.6
# 132                                 NaN                                   NaN
# 133                                 NaN                                   NaN
# 134                                 NaN                                   NaN
# 135                                 NaN                                   NaN
# 136                                 NaN                                   NaN
# 137                                 NaN                                   NaN
# 138                                 NaN                                   NaN
# 139                                 NaN                                   NaN
# 140                                 NaN                                   NaN
# 141                                 NaN                                   NaN
# 142                                 NaN                                   NaN
# 143                                 NaN                                   NaN
# 144                                 NaN                                   NaN
# 145                                 NaN                                   NaN
# 146                                 NaN                                   NaN
#
#      7. Inativos e Pensionistas com Recursos Vinculados  9. Receita Corrente  \
# 127                                       1.918020e+08          4.753895e+09
# 128                                       2.182234e+08          4.603217e+09
# 129                                       2.227669e+08          4.623710e+09
# 130                                       2.232093e+08          4.957853e+09
# 131                                       3.934379e+08          5.373587e+09
# 132                                       2.204016e+08          5.652536e+09
# 133                                       2.054635e+08          5.687448e+09
# 134                                       1.961541e+08          4.727752e+09
# 135                                       2.038257e+08          4.871807e+09
# 136                                       2.370245e+08          5.013924e+09
# 137                                       1.335377e+08          5.184270e+09
# 138                                       3.081464e+08          4.697518e+09
# 139                                       2.225356e+08          5.489205e+09
# 140                                       2.163445e+08          4.915299e+09
# 141                                       2.299560e+08          5.073526e+09
# 142                                       2.096411e+08          5.626793e+09
# 143                                       3.826907e+08          3.171746e+09
# 144                                       2.384640e+08          5.709832e+09
# 145                                       2.181414e+08          6.050547e+09
# 146                                                NaN          3.247994e+09
#
#      10. Deduções
# 127  1.239725e+09
# 128  1.194247e+09
# 129  1.437768e+09
# 130  1.280028e+09
# 131  1.888398e+09
# 132  1.155264e+09
# 133  1.634755e+09
# 134  1.293003e+09
# 135  1.375843e+09
# 136  1.361954e+09
# 137  1.328094e+09
# 138  1.355047e+09
# 139  1.510977e+09
# 140  1.351853e+09
# 141  1.429247e+09
# 142  1.461376e+09
# 143  7.052909e+08
# 144  1.412170e+09
# 145  1.710413e+09
# 146  5.398640e+08

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 9 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   data_Lançamento                                      147 non-null    object
#  1   1. Pessoal Ativo                                     146 non-null    float64
#  2   2. Pessoal Inativo e Pensionistas                    146 non-null    float64
#  3   4. Indenizações por Demissão e Incentivo à Demissão  132 non-null    float64
#  4   5. Decorrentes de Decisão Judicial                   132 non-null    float64
#  5   6. Despesas de Exercicios Anteriores                 132 non-null    float64
#  6   7. Inativos e Pensionistas com Recursos Vinculados   146 non-null    float64
#  7   9. Receita Corrente                                  135 non-null    float64
#  8   10. Deduções                                         135 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 10.5+ KB

# %%
dados['Data'] = pd.to_datetime(dados['data_Lançamento'], format='%m-%Y')

# %%
plt.figure(figsize=(12, 6))

plt.plot('Data', '7. Inativos e Pensionistas com Recursos Vinculados', data=dados, label='Inativos e Pensionistas com Recursos Vinculados',  linestyle='-', color='red')
plt.title('Séries Temporais')
plt.legend() 
plt.xlabel('Data')
plt.ylabel('Valor')
plt.show()

# %%
RV = pd.DataFrame(dados[['Data','7. Inativos e Pensionistas com Recursos Vinculados']])
RV = RV.dropna()

# %% [markdown]
# Tratamento de Outlayers

# %%
teto = RV['7. Inativos e Pensionistas com Recursos Vinculados'].quantile(0.95) # Pega o valor que representa os 95% maiores dados
# Tudo o que for maior que o teto, vira o teto. O que for menor, continua igual.
RV['7. Inativos e Pensionistas com Recursos Vinculados'] = np.clip(RV['7. Inativos e Pensionistas com Recursos Vinculados'], a_min=None, a_max=teto)

# %%
plt.figure(figsize=(12, 6))

plt.plot(RV.index, RV['7. Inativos e Pensionistas com Recursos Vinculados'], label='Inativos e Pensionistas com Recursos Vinculados', linestyle='-', color='red')
plt.title('Séries Temporais')
plt.legend()
plt.xlabel('Data')
plt.ylabel('Valor')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Gráficos ACF e PACF: Pessoal Ativo

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
plot_acf(RV['7. Inativos e Pensionistas com Recursos Vinculados'], ax=axes[0], lags=20)
axes[0].set_title('ACF - Inativos e Pensionistas com Recursos Vinculados')
axes[0].set_xlabel('Lags')
axes[0].set_ylabel('Autocorrelação')  
plot_pacf(RV['7. Inativos e Pensionistas com Recursos Vinculados'], ax=axes[1], lags=20)
axes[1].set_title('PACF - Inativos e Pensionistas com Recursos Vinculados')   
axes[1].set_xlabel('Lags')
axes[1].set_ylabel('Autocorrelação Parcial')
plt.tight_layout()
plt.show()

# %% [markdown]
# Crianção de Lags

# %%
RV.set_index('Data', inplace=True)
for i in range(1, 13):
    RV[f'Lag {i}'] = RV['7. Inativos e Pensionistas com Recursos Vinculados'].shift(i)
RV.dropna(inplace=True)

# %%
#PA.reset_index(drop=True, inplace=True)
RV.head()
# Out:
#             7. Inativos e Pensionistas com Recursos Vinculados         Lag 1  \
# Data
# 2015-01-01                                        162305001.1   4.834269e+08
# 2015-02-01                                        166915091.4   1.623050e+08
# 2015-03-01                                        171047181.4   1.669151e+08
# 2015-04-01                                        154625570.3   1.710472e+08
# 2015-05-01                                        156340802.9   1.546256e+08
#
#                    Lag 2         Lag 3         Lag 4         Lag 5  \
# Data
# 2015-01-01  2.092427e+08  2.711327e+08  4.189295e+08  1.923983e+08
# 2015-02-01  4.834269e+08  2.092427e+08  2.711327e+08  4.189295e+08
# 2015-03-01  1.623050e+08  4.834269e+08  2.092427e+08  2.711327e+08
# 2015-04-01  1.669151e+08  1.623050e+08  4.834269e+08  2.092427e+08
# 2015-05-01  1.710472e+08  1.669151e+08  1.623050e+08  4.834269e+08
#
#                   Lag 6        Lag 7        Lag 8        Lag 9       Lag 10  \
# Data
# 2015-01-01  286323612.9  265985586.1  298774669.7  224522910.7  271377435.4
# 2015-02-01  192398302.0  286323612.9  265985586.1  298774669.7  224522910.7
# 2015-03-01  418929527.6  192398302.0  286323612.9  265985586.1  298774669.7
# 2015-04-01  271132665.3  418929527.6  192398302.0  286323612.9  265985586.1
# 2015-05-01  209242672.0  271132665.3  418929527.6  192398302.0  286323612.9
#
#                  Lag 11       Lag 12
# Data
# 2015-01-01  275530266.8  242785069.3
# 2015-02-01  271377435.4  275530266.8
# 2015-03-01  224522910.7  271377435.4
# 2015-04-01  298774669.7  224522910.7
# 2015-05-01  265985586.1  298774669.7

# %%
RV.tail(10)
# Out:
#             7. Inativos e Pensionistas com Recursos Vinculados         Lag 1  \
# Data
# 2025-05-01                                       2.370245e+08   2.038257e+08
# 2025-06-01                                       1.335377e+08   2.370245e+08
# 2025-07-01                                       3.081464e+08   1.335377e+08
# 2025-08-01                                       2.225356e+08   3.081464e+08
# 2025-09-01                                       2.163445e+08   2.225356e+08
# 2025-10-01                                       2.299560e+08   2.163445e+08
# 2025-11-01                                       2.096411e+08   2.299560e+08
# 2025-12-01                                       3.826907e+08   2.096411e+08
# 2026-01-01                                       2.384640e+08   3.826907e+08
# 2026-02-01                                       2.181414e+08   2.384640e+08
#
#                    Lag 2         Lag 3         Lag 4         Lag 5  \
# Data
# 2025-05-01  1.961541e+08  2.054635e+08  2.204016e+08  3.934379e+08
# 2025-06-01  2.038257e+08  1.961541e+08  2.054635e+08  2.204016e+08
# 2025-07-01  2.370245e+08  2.038257e+08  1.961541e+08  2.054635e+08
# 2025-08-01  1.335377e+08  2.370245e+08  2.038257e+08  1.961541e+08
# 2025-09-01  3.081464e+08  1.335377e+08  2.370245e+08  2.038257e+08
# 2025-10-01  2.225356e+08  3.081464e+08  1.335377e+08  2.370245e+08
# 2025-11-01  2.163445e+08  2.225356e+08  3.081464e+08  1.335377e+08
# 2025-12-01  2.299560e+08  2.163445e+08  2.225356e+08  3.081464e+08
# 2026-01-01  2.096411e+08  2.299560e+08  2.163445e+08  2.225356e+08
# 2026-02-01  3.826907e+08  2.096411e+08  2.299560e+08  2.163445e+08
#
#                    Lag 6         Lag 7         Lag 8         Lag 9  \
# Data
# 2025-05-01  2.232093e+08  2.227669e+08  2.182234e+08  1.918020e+08
# 2025-06-01  3.934379e+08  2.232093e+08  2.227669e+08  2.182234e+08
# 2025-07-01  2.204016e+08  3.934379e+08  2.232093e+08  2.227669e+08
# 2025-08-01  2.054635e+08  2.204016e+08  3.934379e+08  2.232093e+08
# 2025-09-01  1.961541e+08  2.054635e+08  2.204016e+08  3.934379e+08
# 2025-10-01  2.038257e+08  1.961541e+08  2.054635e+08  2.204016e+08
# 2025-11-01  2.370245e+08  2.038257e+08  1.961541e+08  2.054635e+08
# 2025-12-01  1.335377e+08  2.370245e+08  2.038257e+08  1.961541e+08
# 2026-01-01  3.081464e+08  1.335377e+08  2.370245e+08  2.038257e+08
# 2026-02-01  2.225356e+08  3.081464e+08  1.335377e+08  2.370245e+08
#
#                   Lag 10        Lag 11        Lag 12
# Data
# 2025-05-01  3.688867e+08  1.667197e+08  1.327805e+08
# 2025-06-01  1.918020e+08  3.688867e+08  1.667197e+08
# 2025-07-01  2.182234e+08  1.918020e+08  3.688867e+08
# 2025-08-01  2.227669e+08  2.182234e+08  1.918020e+08
# 2025-09-01  2.232093e+08  2.227669e+08  2.182234e+08
# 2025-10-01  3.934379e+08  2.232093e+08  2.227669e+08
# 2025-11-01  2.204016e+08  3.934379e+08  2.232093e+08
# 2025-12-01  2.054635e+08  2.204016e+08  3.934379e+08
# 2026-01-01  1.961541e+08  2.054635e+08  2.204016e+08
# 2026-02-01  2.038257e+08  1.961541e+08  2.054635e+08

# %% [markdown]
# Dividindo entre treino e teste

# %%
y = RV['7. Inativos e Pensionistas com Recursos Vinculados'].values.reshape(-1, 1).astype(float)
X = RV.drop(columns=['7. Inativos e Pensionistas com Recursos Vinculados']).values.astype(float)

# %%
X.shape, y.shape
# Out:
# ((134, 12), (134, 1))

# %%
RV.index[119]
# Out:
# Timestamp('2024-12-01 00:00:00')

# %%
#Treino
X_train = X[:120]
y_train = y[:120]

#Validação
X_val = X[120:132]
y_val = y[120:132]

#Teste
X_test = X[132:]
y_test = y[132:]

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape ,X_test.shape, y_test.shape,
# Out:
# ((120, 12), (120, 1), (12, 12), (12, 1), (2, 12), (2, 1))

# %% [markdown]
# Normalizando os Dados

# %%
# Scaler para as Features X
#scaler_X = MinMaxScaler()
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train) #treino
X_val_scaled = scaler_X.transform(X_val)   # validação
X_test_scaled = scaler_X.transform(X_test) # teste

# Scaler para o Alvo y
#scaler_y = MinMaxScaler()
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train) #treino
y_val_scaled = scaler_y.transform(y_val)   # validação
y_test_scaled = scaler_y.transform(y_test) # teste

# %%
print(f"Máximo no X do treino: {X_train_scaled.max()}, Mínimo: {X_train_scaled.min()}")
print(f"Máximo no X do validação: {X_val_scaled.max()}, Mínimo: {X_val_scaled.min()}")
print(f"Máximo no X do teste: {X_test_scaled.max()}, Mínimo: {X_test_scaled.min()}")
print("---------------------------------")
print(f"Máximo no y do treino: {y_train_scaled.max()}, Mínimo: {y_train_scaled.min()}")
print(f"Máximo no y do validação: {y_val_scaled.max()}, Mínimo: {y_val_scaled.min()}")
print(f"Máximo no y do teste: {y_test_scaled.max()}, Mínimo: {y_test_scaled.min()}")
# Out:
# Máximo no X do treino: 1.6390199357622135, Mínimo: -1.7154068613727476
# Máximo no X do validação: 0.8073033826607158, Mínimo: -1.7506084591571833
# Máximo no X do teste: 0.7095689220205871, Mínimo: -1.6185368259196782
# ---------------------------------
# Máximo no y do treino: 1.6465756393237894, Mínimo: -1.6608390631295473
# Máximo no y do validação: 0.721976703269074, Mínimo: -1.5648546468800546
# Máximo no y do teste: -0.6017973197574172, Mínimo: -0.78832645498882

# %% [markdown]
# Definição de Hiperparâmetros

# %%
hiperparametros = {
    'TAXA_DE_APRENDIZADO': 0.001,
    'EPOCAS': 800,
    'TAMANHO_LOTE': 12,
    'ENTRADAS': 4,
    'UNIDADES_OCULTAS': 2,
    'ATIVACAO': 'tanh',
    'RANDOM_STATE': 42,
    'VALIDACAO': (X_val_scaled, y_val_scaled),
    "DROPOUT_RATE": 0.2
    
}

# %%
#Construção da arquitetura

#Camada de Entrada
model_mlp = Sequential([Dense(hiperparametros['ENTRADAS'], # 64 Neurônio nesta camada (Z = W*X + b)
                                  input_shape=(X_train_scaled.shape[1],), # Quantidade de variáveis que vão entrar ( Z = w1*x1 + w2*x2 + b)
                                  activation=hiperparametros['ATIVACAO']) ]) # Especificando qual vai ser o tipo de ativação. Ex: reLu, linear, tanh, sigmoid...

#Dropout entre as camadas para evitar overfitting
#model_mlp.add(Dropout(hiperparametros['DROPOUT_RATE'])) # Adiciona uma camada de Dropout para ajudar a prevenir overfitting, desligando aleatoriamente 20% dos neurônios durante o treinamento

#Camada Oculta 1
model_mlp.add(Dense(hiperparametros['UNIDADES_OCULTAS'], activation=hiperparametros['ATIVACAO']))

#Dropout entre as camadas para evitar overfitting
#model_mlp.add(Dropout(hiperparametros['DROPOUT_RATE'])) # Adiciona uma camada de Dropout para ajudar a prevenir overfitting, desligando aleatoriamente 20% dos neurônios durante o treinamento

#Camada de Saída
model_mlp.add(Dense(1, activation='linear')) # 1 Neurônio nesta camada (Z = W*X + b) 


#Configuração
model_mlp.compile(
    optimizer=Adam(learning_rate=hiperparametros['TAXA_DE_APRENDIZADO']), #Aplicação do modelo de Gradiente descendente, usando o leanning rate proposto
    loss='mse', # Qual a função da loss. Nesse caso o mse é (Z - F(x1,x2))²
    metrics=['mae'] # Erro Médio Absoluto para termos uma métrica mais legível
)


## Define a regra de parada
parada_antecipada = EarlyStopping(
    monitor='val_loss', # Fica de olho no erro de validação
    patience=50,        # Se o erro não cair por 50 épocas seguidas, ele para
    restore_best_weights=True # Garante que você ficará com os melhores pesos encontrados
)



#Treinamento
historico = model_mlp.fit(
    X_train_scaled, y_train_scaled, #Indica quais são as bases
    epochs=hiperparametros['EPOCAS'], 
    batch_size=hiperparametros['TAMANHO_LOTE'], #O batch_size é a batelada de cada iteração (epoch) que será calculada
    validation_data=hiperparametros['VALIDACAO'], #Indica qual é a base de validação
    shuffle=False, # Manter a ordem temporal dos dados
    verbose=1, # Mude para 1 se quiser ver o log de cada época,
    callbacks=[parada_antecipada] # Early Stopping para evitar overfitting
)
# Out:
# Epoch 1/800
# c:\Projeto Series Temporais\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0241 - mae: 0.7770 - val_loss: 0.6878 - val_mae: 0.6051
# Epoch 2/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9877 - mae: 0.7576 - val_loss: 0.6595 - val_mae: 0.5959
# Epoch 3/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9585 - mae: 0.7424 - val_loss: 0.6353 - val_mae: 0.5873
# Epoch 4/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9317 - mae: 0.7286 - val_loss: 0.6144 - val_mae: 0.5792
# Epoch 5/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9067 - mae: 0.7160 - val_loss: 0.5964 - val_mae: 0.5717
# Epoch 6/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8830 - mae: 0.7044 - val_loss: 0.5806 - val_mae: 0.5649
# Epoch 7/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8606 - mae: 0.6935 - val_loss: 0.5667 - val_mae: 0.5585
# Epoch 8/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8393 - mae: 0.6832 - val_loss: 0.5544 - val_mae: 0.5526
# Epoch 9/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8189 - mae: 0.6741 - val_loss: 0.5435 - val_mae: 0.5472
# Epoch 10/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7994 - mae: 0.6657 - val_loss: 0.5336 - val_mae: 0.5421
# Epoch 11/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7808 - mae: 0.6576 - val_loss: 0.5248 - val_mae: 0.5375
# Epoch 12/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7630 - mae: 0.6497 - val_loss: 0.5168 - val_mae: 0.5331
# Epoch 13/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7460 - mae: 0.6420 - val_loss: 0.5095 - val_mae: 0.5290
# Epoch 14/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7297 - mae: 0.6348 - val_loss: 0.5029 - val_mae: 0.5253
# Epoch 15/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7142 - mae: 0.6286 - val_loss: 0.4969 - val_mae: 0.5217
# Epoch 16/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6995 - mae: 0.6226 - val_loss: 0.4913 - val_mae: 0.5184
# Epoch 17/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6854 - mae: 0.6167 - val_loss: 0.4861 - val_mae: 0.5152
# Epoch 18/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6720 - mae: 0.6111 - val_loss: 0.4813 - val_mae: 0.5137
# Epoch 19/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6593 - mae: 0.6058 - val_loss: 0.4768 - val_mae: 0.5128
# Epoch 20/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6473 - mae: 0.6007 - val_loss: 0.4725 - val_mae: 0.5119
# Epoch 21/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6360 - mae: 0.5959 - val_loss: 0.4684 - val_mae: 0.5110
# Epoch 22/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6252 - mae: 0.5912 - val_loss: 0.4645 - val_mae: 0.5102
# Epoch 23/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6151 - mae: 0.5867 - val_loss: 0.4607 - val_mae: 0.5094
# Epoch 24/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6056 - mae: 0.5823 - val_loss: 0.4571 - val_mae: 0.5086
# Epoch 25/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5966 - mae: 0.5781 - val_loss: 0.4535 - val_mae: 0.5078
# Epoch 26/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5881 - mae: 0.5741 - val_loss: 0.4501 - val_mae: 0.5070
# Epoch 27/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5802 - mae: 0.5704 - val_loss: 0.4467 - val_mae: 0.5062
# Epoch 28/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5727 - mae: 0.5671 - val_loss: 0.4435 - val_mae: 0.5054
# Epoch 29/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5656 - mae: 0.5640 - val_loss: 0.4403 - val_mae: 0.5045
# Epoch 30/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5589 - mae: 0.5609 - val_loss: 0.4372 - val_mae: 0.5037
# Epoch 31/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5526 - mae: 0.5579 - val_loss: 0.4341 - val_mae: 0.5029
# Epoch 32/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5467 - mae: 0.5550 - val_loss: 0.4311 - val_mae: 0.5020
# Epoch 33/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5411 - mae: 0.5522 - val_loss: 0.4282 - val_mae: 0.5012
# Epoch 34/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5358 - mae: 0.5496 - val_loss: 0.4254 - val_mae: 0.5003
# Epoch 35/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5308 - mae: 0.5470 - val_loss: 0.4226 - val_mae: 0.4995
# Epoch 36/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5260 - mae: 0.5444 - val_loss: 0.4199 - val_mae: 0.4986
# Epoch 37/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5214 - mae: 0.5420 - val_loss: 0.4173 - val_mae: 0.4978
# Epoch 38/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5171 - mae: 0.5396 - val_loss: 0.4147 - val_mae: 0.4969
# Epoch 39/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5130 - mae: 0.5373 - val_loss: 0.4122 - val_mae: 0.4961
# Epoch 40/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5090 - mae: 0.5351 - val_loss: 0.4097 - val_mae: 0.4952
# Epoch 41/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5052 - mae: 0.5329 - val_loss: 0.4073 - val_mae: 0.4944
# Epoch 42/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5016 - mae: 0.5308 - val_loss: 0.4050 - val_mae: 0.4935
# Epoch 43/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4981 - mae: 0.5288 - val_loss: 0.4027 - val_mae: 0.4927
# Epoch 44/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4948 - mae: 0.5268 - val_loss: 0.4004 - val_mae: 0.4918
# Epoch 45/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4915 - mae: 0.5248 - val_loss: 0.3982 - val_mae: 0.4910
# Epoch 46/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4884 - mae: 0.5231 - val_loss: 0.3961 - val_mae: 0.4901
# Epoch 47/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4854 - mae: 0.5213 - val_loss: 0.3939 - val_mae: 0.4893
# Epoch 48/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4825 - mae: 0.5197 - val_loss: 0.3919 - val_mae: 0.4884
# Epoch 49/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4796 - mae: 0.5180 - val_loss: 0.3898 - val_mae: 0.4876
# Epoch 50/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4769 - mae: 0.5164 - val_loss: 0.3878 - val_mae: 0.4867
# Epoch 51/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4742 - mae: 0.5148 - val_loss: 0.3859 - val_mae: 0.4858
# Epoch 52/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4716 - mae: 0.5133 - val_loss: 0.3840 - val_mae: 0.4850
# Epoch 53/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4691 - mae: 0.5117 - val_loss: 0.3821 - val_mae: 0.4841
# Epoch 54/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4666 - mae: 0.5103 - val_loss: 0.3803 - val_mae: 0.4832
# Epoch 55/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4642 - mae: 0.5089 - val_loss: 0.3784 - val_mae: 0.4823
# Epoch 56/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4619 - mae: 0.5076 - val_loss: 0.3767 - val_mae: 0.4817
# Epoch 57/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4596 - mae: 0.5063 - val_loss: 0.3749 - val_mae: 0.4816
# Epoch 58/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4573 - mae: 0.5049 - val_loss: 0.3732 - val_mae: 0.4814
# Epoch 59/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4551 - mae: 0.5036 - val_loss: 0.3716 - val_mae: 0.4813
# Epoch 60/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4530 - mae: 0.5024 - val_loss: 0.3699 - val_mae: 0.4811
# Epoch 61/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4509 - mae: 0.5012 - val_loss: 0.3683 - val_mae: 0.4809
# Epoch 62/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4488 - mae: 0.5001 - val_loss: 0.3667 - val_mae: 0.4807
# Epoch 63/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4468 - mae: 0.4989 - val_loss: 0.3652 - val_mae: 0.4805
# Epoch 64/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4448 - mae: 0.4978 - val_loss: 0.3637 - val_mae: 0.4803
# Epoch 65/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4428 - mae: 0.4967 - val_loss: 0.3622 - val_mae: 0.4801
# Epoch 66/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4409 - mae: 0.4956 - val_loss: 0.3607 - val_mae: 0.4799
# Epoch 67/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4390 - mae: 0.4945 - val_loss: 0.3593 - val_mae: 0.4796
# Epoch 68/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4371 - mae: 0.4935 - val_loss: 0.3579 - val_mae: 0.4794
# Epoch 69/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4352 - mae: 0.4926 - val_loss: 0.3565 - val_mae: 0.4792
# Epoch 70/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4334 - mae: 0.4916 - val_loss: 0.3552 - val_mae: 0.4789
# Epoch 71/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4316 - mae: 0.4907 - val_loss: 0.3539 - val_mae: 0.4787
# Epoch 72/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4299 - mae: 0.4899 - val_loss: 0.3526 - val_mae: 0.4784
# Epoch 73/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4281 - mae: 0.4890 - val_loss: 0.3514 - val_mae: 0.4781
# Epoch 74/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4264 - mae: 0.4882 - val_loss: 0.3502 - val_mae: 0.4779
# Epoch 75/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4247 - mae: 0.4874 - val_loss: 0.3490 - val_mae: 0.4776
# Epoch 76/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4230 - mae: 0.4867 - val_loss: 0.3479 - val_mae: 0.4773
# Epoch 77/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4214 - mae: 0.4860 - val_loss: 0.3467 - val_mae: 0.4771
# Epoch 78/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4197 - mae: 0.4854 - val_loss: 0.3457 - val_mae: 0.4768
# Epoch 79/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4181 - mae: 0.4847 - val_loss: 0.3446 - val_mae: 0.4765
# Epoch 80/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4165 - mae: 0.4840 - val_loss: 0.3436 - val_mae: 0.4762
# Epoch 81/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4150 - mae: 0.4834 - val_loss: 0.3426 - val_mae: 0.4760
# Epoch 82/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4134 - mae: 0.4829 - val_loss: 0.3417 - val_mae: 0.4757
# Epoch 83/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4119 - mae: 0.4823 - val_loss: 0.3407 - val_mae: 0.4754
# Epoch 84/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4104 - mae: 0.4818 - val_loss: 0.3398 - val_mae: 0.4751
# Epoch 85/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4089 - mae: 0.4813 - val_loss: 0.3390 - val_mae: 0.4749
# Epoch 86/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4074 - mae: 0.4807 - val_loss: 0.3382 - val_mae: 0.4746
# Epoch 87/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4059 - mae: 0.4802 - val_loss: 0.3374 - val_mae: 0.4743
# Epoch 88/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4045 - mae: 0.4797 - val_loss: 0.3366 - val_mae: 0.4740
# Epoch 89/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4031 - mae: 0.4792 - val_loss: 0.3359 - val_mae: 0.4738
# Epoch 90/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4017 - mae: 0.4787 - val_loss: 0.3352 - val_mae: 0.4735
# Epoch 91/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4003 - mae: 0.4783 - val_loss: 0.3345 - val_mae: 0.4732
# Epoch 92/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3989 - mae: 0.4778 - val_loss: 0.3339 - val_mae: 0.4730
# Epoch 93/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3976 - mae: 0.4773 - val_loss: 0.3333 - val_mae: 0.4727
# Epoch 94/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3962 - mae: 0.4769 - val_loss: 0.3327 - val_mae: 0.4725
# Epoch 95/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3949 - mae: 0.4764 - val_loss: 0.3322 - val_mae: 0.4722
# Epoch 96/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3937 - mae: 0.4759 - val_loss: 0.3317 - val_mae: 0.4720
# Epoch 97/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3924 - mae: 0.4754 - val_loss: 0.3312 - val_mae: 0.4717
# Epoch 98/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3911 - mae: 0.4749 - val_loss: 0.3307 - val_mae: 0.4715
# Epoch 99/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3899 - mae: 0.4744 - val_loss: 0.3303 - val_mae: 0.4712
# Epoch 100/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3887 - mae: 0.4739 - val_loss: 0.3299 - val_mae: 0.4710
# Epoch 101/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3875 - mae: 0.4734 - val_loss: 0.3295 - val_mae: 0.4708
# Epoch 102/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3863 - mae: 0.4728 - val_loss: 0.3291 - val_mae: 0.4705
# Epoch 103/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3852 - mae: 0.4723 - val_loss: 0.3288 - val_mae: 0.4703
# Epoch 104/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3841 - mae: 0.4718 - val_loss: 0.3285 - val_mae: 0.4701
# Epoch 105/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3829 - mae: 0.4713 - val_loss: 0.3282 - val_mae: 0.4699
# Epoch 106/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3818 - mae: 0.4708 - val_loss: 0.3280 - val_mae: 0.4696
# Epoch 107/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3808 - mae: 0.4702 - val_loss: 0.3277 - val_mae: 0.4694
# Epoch 108/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3797 - mae: 0.4697 - val_loss: 0.3275 - val_mae: 0.4692
# Epoch 109/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3787 - mae: 0.4692 - val_loss: 0.3273 - val_mae: 0.4690
# Epoch 110/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3776 - mae: 0.4686 - val_loss: 0.3271 - val_mae: 0.4688
# Epoch 111/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3766 - mae: 0.4681 - val_loss: 0.3269 - val_mae: 0.4686
# Epoch 112/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3756 - mae: 0.4676 - val_loss: 0.3268 - val_mae: 0.4684
# Epoch 113/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3747 - mae: 0.4670 - val_loss: 0.3267 - val_mae: 0.4682
# Epoch 114/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3737 - mae: 0.4665 - val_loss: 0.3266 - val_mae: 0.4680
# Epoch 115/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3728 - mae: 0.4660 - val_loss: 0.3265 - val_mae: 0.4678
# Epoch 116/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3718 - mae: 0.4655 - val_loss: 0.3264 - val_mae: 0.4676
# Epoch 117/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3709 - mae: 0.4650 - val_loss: 0.3263 - val_mae: 0.4675
# Epoch 118/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3700 - mae: 0.4645 - val_loss: 0.3263 - val_mae: 0.4673
# Epoch 119/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3691 - mae: 0.4641 - val_loss: 0.3263 - val_mae: 0.4671
# Epoch 120/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3683 - mae: 0.4636 - val_loss: 0.3262 - val_mae: 0.4669
# Epoch 121/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3674 - mae: 0.4631 - val_loss: 0.3262 - val_mae: 0.4668
# Epoch 122/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3666 - mae: 0.4627 - val_loss: 0.3262 - val_mae: 0.4666
# Epoch 123/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3658 - mae: 0.4622 - val_loss: 0.3262 - val_mae: 0.4664
# Epoch 124/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3649 - mae: 0.4618 - val_loss: 0.3263 - val_mae: 0.4663
# Epoch 125/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3641 - mae: 0.4613 - val_loss: 0.3263 - val_mae: 0.4661
# Epoch 126/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3634 - mae: 0.4608 - val_loss: 0.3263 - val_mae: 0.4660
# Epoch 127/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3626 - mae: 0.4604 - val_loss: 0.3264 - val_mae: 0.4658
# Epoch 128/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3618 - mae: 0.4600 - val_loss: 0.3264 - val_mae: 0.4657
# Epoch 129/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3611 - mae: 0.4596 - val_loss: 0.3265 - val_mae: 0.4655
# Epoch 130/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3603 - mae: 0.4593 - val_loss: 0.3266 - val_mae: 0.4654
# Epoch 131/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3596 - mae: 0.4589 - val_loss: 0.3267 - val_mae: 0.4653
# Epoch 132/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3589 - mae: 0.4585 - val_loss: 0.3268 - val_mae: 0.4651
# Epoch 133/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3582 - mae: 0.4582 - val_loss: 0.3269 - val_mae: 0.4650
# Epoch 134/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3575 - mae: 0.4578 - val_loss: 0.3270 - val_mae: 0.4649
# Epoch 135/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3568 - mae: 0.4574 - val_loss: 0.3271 - val_mae: 0.4647
# Epoch 136/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3561 - mae: 0.4571 - val_loss: 0.3272 - val_mae: 0.4646
# Epoch 137/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3554 - mae: 0.4567 - val_loss: 0.3273 - val_mae: 0.4645
# Epoch 138/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3548 - mae: 0.4563 - val_loss: 0.3274 - val_mae: 0.4644
# Epoch 139/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3541 - mae: 0.4560 - val_loss: 0.3275 - val_mae: 0.4642
# Epoch 140/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3535 - mae: 0.4556 - val_loss: 0.3277 - val_mae: 0.4641
# Epoch 141/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3528 - mae: 0.4553 - val_loss: 0.3278 - val_mae: 0.4640
# Epoch 142/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3522 - mae: 0.4550 - val_loss: 0.3279 - val_mae: 0.4639
# Epoch 143/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3516 - mae: 0.4547 - val_loss: 0.3281 - val_mae: 0.4638
# Epoch 144/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3510 - mae: 0.4544 - val_loss: 0.3282 - val_mae: 0.4636
# Epoch 145/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3504 - mae: 0.4541 - val_loss: 0.3283 - val_mae: 0.4635
# Epoch 146/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3498 - mae: 0.4538 - val_loss: 0.3285 - val_mae: 0.4634
# Epoch 147/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3492 - mae: 0.4535 - val_loss: 0.3286 - val_mae: 0.4633
# Epoch 148/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3486 - mae: 0.4533 - val_loss: 0.3288 - val_mae: 0.4632
# Epoch 149/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3481 - mae: 0.4530 - val_loss: 0.3289 - val_mae: 0.4631
# Epoch 150/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3475 - mae: 0.4527 - val_loss: 0.3290 - val_mae: 0.4630
# Epoch 151/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3469 - mae: 0.4524 - val_loss: 0.3292 - val_mae: 0.4629
# Epoch 152/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3464 - mae: 0.4522 - val_loss: 0.3293 - val_mae: 0.4627
# Epoch 153/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3458 - mae: 0.4519 - val_loss: 0.3295 - val_mae: 0.4626
# Epoch 154/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3453 - mae: 0.4516 - val_loss: 0.3296 - val_mae: 0.4625
# Epoch 155/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3448 - mae: 0.4514 - val_loss: 0.3297 - val_mae: 0.4624
# Epoch 156/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3442 - mae: 0.4511 - val_loss: 0.3299 - val_mae: 0.4623
# Epoch 157/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3437 - mae: 0.4509 - val_loss: 0.3300 - val_mae: 0.4622
# Epoch 158/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3432 - mae: 0.4506 - val_loss: 0.3301 - val_mae: 0.4621
# Epoch 159/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3427 - mae: 0.4504 - val_loss: 0.3303 - val_mae: 0.4620
# Epoch 160/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3422 - mae: 0.4501 - val_loss: 0.3304 - val_mae: 0.4618
# Epoch 161/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3417 - mae: 0.4499 - val_loss: 0.3305 - val_mae: 0.4617
# Epoch 162/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3412 - mae: 0.4496 - val_loss: 0.3306 - val_mae: 0.4616
# Epoch 163/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3407 - mae: 0.4494 - val_loss: 0.3308 - val_mae: 0.4615
# Epoch 164/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3402 - mae: 0.4491 - val_loss: 0.3309 - val_mae: 0.4614
# Epoch 165/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3397 - mae: 0.4489 - val_loss: 0.3310 - val_mae: 0.4613
# Epoch 166/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3392 - mae: 0.4486 - val_loss: 0.3311 - val_mae: 0.4611
# Epoch 167/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3388 - mae: 0.4484 - val_loss: 0.3312 - val_mae: 0.4610
# Epoch 168/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3383 - mae: 0.4481 - val_loss: 0.3313 - val_mae: 0.4609
# Epoch 169/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3378 - mae: 0.4479 - val_loss: 0.3315 - val_mae: 0.4608
# Epoch 170/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3374 - mae: 0.4476 - val_loss: 0.3316 - val_mae: 0.4606
# Epoch 171/800
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3369 - mae: 0.4473 - val_loss: 0.3317 - val_mae: 0.4605

# %%
model_mlp.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 4)              │            52 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 197 (792.00 B)
#  Trainable params: 65 (260.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 132 (532.00 B)

# %%
# get_weights() retorna uma lista: o primeiro item é a matriz de pesos (W), o segundo é o viés (b)
pesos, vies = model_mlp.get_layer(index=0).get_weights()

print(f"pesos: {pesos.flatten()} e o viés: {vies[0]:.4f}")
# Out:
# pesos: [ 0.02188546 -0.29126707 -0.74535495  0.48474872 -0.03986543  0.49421957
#  -0.09739542  0.49650276  0.34240946  0.6702441  -0.03676453  0.1863134
#   0.12067672 -0.19642106 -0.10625432  0.28608453  0.10398886  0.08619768
#   0.05647993 -0.12551701 -0.25680026  0.06504805 -0.0609464   0.70656765
#  -0.19368091  0.36853337  0.00569364 -0.22056808  0.13774993  0.5759836
#   0.30353603  0.31210324  0.01335502  0.21395902  0.07594448  0.51537716
#  -0.8314404  -0.2519687  -0.33028108 -0.36963442  0.2691118  -0.22024372
#  -0.03447461 -0.17381679  0.6390808   0.06568158  0.03310029 -0.5177495 ] e o viés: -0.0977

# %%
#data_min = scaler_X.data_min_
#scale = scaler_X.scale_

# w = pesos / scale (scale is the range: 1/(max - min))
#w = pesos / scale[:, np.newaxis]
#b_raw = vies - np.dot(data_min, w)

#w_escalar = w[0][0]
#b_raw_escalar = b_raw[0]

#print(f"Pesos desnormalizados: {w.flatten()}")
#print(f"Viés desnormalizado: {b_raw_escalar:.4f}")

# %%
plt.figure(figsize=(10, 5))

# Plotando a Perda (MSE)
plt.subplot(1, 2, 1)
plt.plot(historico.history['loss'], label='Erro Quadrático Médio (MSE)', color='red')
plt.title('Curva de Aprendizado - Loss')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)

# Plotando a Métrica (MAE)
plt.subplot(1, 2, 2)
plt.plot(historico.history['mae'], label='Erro Médio Absoluto (MAE)', color='blue')
plt.title('Evolução da Métrica - MAE')
plt.xlabel('Épocas')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
erro_simples = model_mlp.evaluate(X_test_scaled, y_test_scaled, verbose=0)[1]
print(f"Erro Médio Absoluto (Simples): {erro_simples:.2f}\n")
# Out:
# Erro Médio Absoluto (Simples): 0.15

# %%
# Criando a figura para as curvas de perda (Loss)
plt.figure(figsize=(12, 5))

# Plotando a Perda de Treino
plt.plot(historico.history['loss'], label='Erro de Treino (MSE)', color='blue')

# Plotando a Perda de Validação (se você passou validation_data no fit)
if 'val_loss' in historico.history:
    plt.plot(historico.history['val_loss'], label='Erro de Validação (MSE)', color='red')

plt.title('Diagnóstico de Overfitting: Curva de Aprendizado')
plt.xlabel('Épocas')
plt.ylabel('Erro (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# O earlystop evitou que o erro aumentasse de acordo com as epocas seguintes. Porém, o GAP entre os conjuntos de teste e validação indica um overfeting pois o conjunto de teste FALHOU em aplicar de forma acertiva no conjunto de validação.

# %%
# Fazer as previsões usando o X de teste normalizado
y_pred_scaled = model_mlp.predict(X_test_scaled)

# Desfazer a normalização das previsões e dos valores reais
y_pred_original = scaler_y.inverse_transform(y_pred_scaled)
y_test_original = scaler_y.inverse_transform(y_test_scaled) # ou apenas use o seu y_test original

# Calcular as métricas na escala real do negócio
mae_real = mean_absolute_error(y_test_original, y_pred_original)
mse_real = mean_squared_error(y_test_original, y_pred_original)
rmse_real = np.sqrt(mse_real)

print(f"--- Desempenho no Teste (Escala Original) ---")
print(f"MAE (Erro Médio Absoluto): {mae_real:.4f}")
print(f"RMSE (Raiz do Erro Quadrático): {rmse_real:.4f}")

# 4. Plotar o gráfico com os dados reais
plt.figure(figsize=(10, 6))
plt.plot(y_test_original, label='Valores Reais', marker='o', color='tab:blue')
plt.plot(y_pred_original, label='Previsões MLP', marker='x', color='tab:orange')

plt.title('Previsões vs Valores Reais - Escala Original')
plt.xlabel('Amostras de Teste')
plt.ylabel('Valor') # Aqui os valores estarão na sua grandeza original (R$, quantidades, etc.)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# --- Desempenho no Teste (Escala Original) ---
# MAE (Erro Médio Absoluto): 15854195.2400
# RMSE (Raiz do Erro Quadrático): 22179606.8603

# %%
# --- 1. DEFINIÇÃO DO PONTO DE PARTIDA ---
# y_pred_scaled contém as previsões que o modelo já fez para o período de teste (Jan, Fev, Mar)
previsoes_existentes = list(y_pred_scaled.flatten()) 
passos_restantes = 12 - len(previsoes_existentes) # Quantos meses faltam para fechar o ano

n_lags = model_mlp.input_shape[1]
# A semente para o futuro precisa ser a última janela de "Teste" que o modelo previu
ultima_sequencia = X_test_scaled[-1].copy()

# --- 2. LOOP RECURSIVO PARA OS MESES FALTANTES ---
for _ in range(passos_restantes):
    # Prevemos o próximo mês baseado na última sequência
    pred_scaled = model_mlp.predict(ultima_sequencia.reshape(1, n_lags), verbose=0)[0, 0]
    previsoes_existentes.append(pred_scaled)
    
    # Atualizamos a janela para a próxima iteração
    ultima_sequencia = np.append(ultima_sequencia[1:], pred_scaled)

# --- 3. CONSOLIDAÇÃO E REVERSÃO DE ESCALA ---
# Agora 'previsoes_existentes' tem exatamente 12 valores (O ano de 2026 completo)
ano_2026_scaled = np.array(previsoes_existentes).reshape(-1, 1)
ano_2026_original = scaler_y.inverse_transform(ano_2026_scaled)

print(f"--- ANO DE 2026 COMPLETO (TESTE + RECURSIVO) ---")
meses = ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun", "Jul", "Ago", "Set", "Out", "Nov", "Dez"]
for i, valor in enumerate(ano_2026_original):
    tipo = "Teste" if i < len(y_pred_scaled) else "Recursivo"
    print(f"{meses[i]}/2026: {valor[0]:,.2f} ({tipo})")

# --- 4. VISUALIZAÇÃO ---
plt.figure(figsize=(12, 6))

# Eixo X para os 12 meses
eixo_2026 = np.arange(1, 13)

# Plotamos o real disponível (os pontos que você já tinha no teste)
plt.plot(eixo_2026[:len(y_test_original)], y_test_original, 
         label='Valores Reais (Disponíveis)', marker='o', color='tab:blue', ls='None')

# Plotamos a linha completa da MLP (3 meses de teste + 9 meses projetados)
plt.plot(eixo_2026, ano_2026_original, 
         label='MLP: Ano 2026 Completo', marker='x', linestyle='--', color='tab:red')

plt.title('Projeção Consolidada: Ano de 2026', fontsize=14)
plt.xticks(eixo_2026, meses)
plt.ylabel('Valor (Escala Original)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# --- ANO DE 2026 COMPLETO (TESTE + RECURSIVO) ---
# Jan/2026: 269,828,800.00 (Teste)
# Fev/2026: 217,797,840.00 (Teste)
# Mar/2026: 217,797,840.00 (Recursivo)
# Abr/2026: 272,044,224.00 (Recursivo)
# Mai/2026: 234,439,536.00 (Recursivo)
# Jun/2026: 220,952,368.00 (Recursivo)
# Jul/2026: 208,713,168.00 (Recursivo)
# Ago/2026: 194,970,400.00 (Recursivo)
# Set/2026: 214,659,920.00 (Recursivo)
# Out/2026: 194,050,224.00 (Recursivo)
# Nov/2026: 196,694,960.00 (Recursivo)
# Dez/2026: 193,293,552.00 (Recursivo)
